# %% [markdown]
# # Single-task Models (Baseline)

# %% [markdown]
# ## Single-Task Model # 1: Rideable-type classifier

# %%
# !python stm_rideable.py --data-dir data/model_ready --epochs 15 --batch-size 4096 --lr 1e-3 --device cuda
# Out:
# [INFO] Using device: cuda
# [INFO] Loading artifacts: data/model_ready/phase3_artifacts.pkl
# [INFO] Category sizes:
#   start_stations=1807, end_stations=1802, member_types=3, ride_types=4
#   numeric_features=10
# [INFO] Train n=532281 (partial), Val n=151832, Test n=297877
# /home/birvas/anaconda3/envs/cyclistic-hvae/lib/python3.10/site-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#
# ===== Epoch 1/15 =====
# ...

# %% [markdown]
# ## Single-Task Model #2: Duration model

# %%
# !python stm_duration.py --data-dir data/model_ready --epochs 15 --batch-size 4096 --lr 1e-3 --device cuda
# Out:
# [INFO] Using device: cuda
# [INFO] Loading artifacts: data/model_ready/phase3_artifacts.pkl
# [INFO] Train n=1064563 (partial), Val n=151832, Test n=297877
# /home/birvas/anaconda3/envs/cyclistic-hvae/lib/python3.10/site-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#
# ===== Epoch 1/15 =====
# ...

# %% [markdown]
# ## Single-Task Model #3: Member vs Casual

# %%
# !python stm_member.py --data-dir data/model_ready --epochs 12 --batch-size 4096 --lr 1e-3 --device cuda
# Out:
# [INFO] Using device: cuda
# [INFO] Loading artifacts: data/model_ready/phase3_artifacts.pkl
# [INFO] Train n=532281 (partial), Val n=151832, Test n=297877
#
# ===== Epoch 1/12 =====
# [TRAIN] loss=0.6513, acc=64.63%
# [VAL]   loss=0.4957, acc=80.87%
# [INFO] Saved best STM checkpoint: stm_member_best.pt
#
# ===== Epoch 2/12 =====
# [TRAIN] loss=0.6058, acc=67.82%
# [VAL]   loss=0.5157, acc=79.23%
# [INFO] No improvement (1/3).
#
# ===== Epoch 3/12 =====
# [TRAIN] loss=0.5978, acc=68.63%
# [VAL]   loss=0.4941, acc=80.62%
# [INFO] Saved best STM checkpoint: stm_member_best.pt
#
# ===== Epoch 4/12 =====
# [TRAIN] loss=0.5924, acc=69.04%
# [VAL]   loss=0.5024, acc=80.23%
# [INFO] No improvement (1/3).
#
# ===== Epoch 5/12 =====
# [TRAIN] loss=0.5876, acc=69.41%
# [VAL]   loss=0.4894, acc=81.01%
# [INFO] Saved best STM checkpoint: stm_member_best.pt
#
# ===== Epoch 6/12 =====
# [TRAIN] loss=0.5833, acc=69.75%
# [VAL]   loss=0.4947, acc=80.47%
# [INFO] No improvement (1/3).
#
# ...
