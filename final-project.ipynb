# %% [markdown]
# # ECE5831 - Final Project: Multi-Task Rider Behavior Modeling for Micromobility Systems

# %% [markdown]
# # Phase 1: Data preparation

# %% [markdown]
# This phase downloads/loads the raw Divvy/Cyclistic trip data and applies core cleaning rules to produce a consistent, analysis-ready dataset. We validate schema and datatypes, remove duplicates and invalid trips (e.g., missing timestamps/stations, negative/zero durations), and standardize time fields so downstream steps use a reliable foundation.

# %%
# !python phase1_data_preparation.py
# Out:
# [INFO] Ensuring clean and parsed datetime columns are consistent...
# [INFO] Creating clean column 'started_at_clean' from 'started_at'...
# [INFO] Creating parsed column 'started_at_parsed' from 'started_at_clean'...
# [INFO] Column 'started_at_parsed': missing before=4,755,050, after=0 (fixed 4,755,050)
# [INFO] Creating clean column 'ended_at_clean' from 'ended_at'...
# [INFO] Creating parsed column 'ended_at_parsed' from 'ended_at_clean'...
# [INFO] Column 'ended_at_parsed': missing before=4,755,050, after=0 (fixed 4,755,050)
# [INFO] Validating columns and dtypes...
# [CHECK] Null count in 'started_at_parsed': 0
# [CHECK] Null count in 'ended_at_parsed': 0
# [INFO] Adding duration features based on started_at_parsed / ended_at_parsed...
# [INFO] Filtering trips with invalid durations (negative or > 24h)...
# [INFO] Removing 7,041 trips with invalid durations.
# [INFO] Running Phase 1 summary checks...
#
# ================================================================================
# PHASE 1 SUMMARY: DATASET OVERVIEW
# ================================================================================
#
# [1] SHAPE
#   Rows   : 5,772,527
#   Columns: 19
#
# [2] DATE RANGE (started_at_parsed)
#   Min: 2024-04-01 00:00:42
#   Max: 2025-03-31 23:50:16.157000
#
# [3] NULL COUNTS (key columns)
# ride_id                    0
# rideable_type              0
# start_station_id     1091133
# end_station_id       1114061
# member_casual              0
# started_at_parsed          0
# ended_at_parsed            0
# dtype: int64
#
# [4] TRIP DURATION SUMMARY (minutes)
# count    5.772527e+06
# mean     1.527964e+01
# std      2.990354e+01
# min      0.000000e+00
# 1%       2.954000e-01
# 5%       2.250600e+00
# 50%      9.651567e+00
# 95%      4.205955e+01
# 99%      9.407585e+01
# max      1.439935e+03
# Name: trip_duration_min, dtype: float64
#
#     Sanity checks:
#       Negative durations (< 0 min): 0
#       > 24 hours (> 1440 min)     : 0
#
# [5] RIDER TYPE BREAKDOWN (member_casual)
# member_casual
# member    3643137
# casual    2129390
# Name: count, dtype: int64
#
# [6] BIKE TYPE BREAKDOWN (rideable_type)
# rideable_type
# electric_bike       3051469
# classic_bike        2576721
# electric_scooter     144337
# Name: count, dtype: int64
#
# [7] TOP 5 START STATIONS (by trip count)
# start_station_id
# 13022           65016
# 13300           43361
# KA1503000043    40510
# 13042           39296
# LF-005          39294
# Name: count, dtype: int64
#
# [8] SAMPLE ROWS
#             ride_id  rideable_type  ... trip_duration_sec trip_duration_min
# 0  743252713F32516B   classic_bike  ...             275.0          4.583333
# 1  BE90D33D2240C614  electric_bike  ...             177.0          2.950000
# 2  D47BBDDE7C40DD61   classic_bike  ...             978.0         16.300000
# 3  6684E760BF9EA9B5   classic_bike  ...             226.0          3.766667
# 4  CA9EFC0D24C24A27  electric_bike  ...            2242.0         37.366667
#
# [5 rows x 19 columns]
#
# ================================================================================
# End of Phase 1 summary. If everything above looks reasonable,
# we are safe to proceed to Phase 2 (feature engineering / modeling).
# ================================================================================
#
# [INFO] Saving processed Phase 1 dataset...
#
# [INFO] Phase 1 dataset saved to: data/processed/full_bike_dataset_phase1.parquet

# %% [markdown]
# # Phase 2: Feature engineering

# %% [markdown]
# This phase derives modeling features from the cleaned trips, including time-based signals (year/month/day/hour/weekday, weekend flags), trip structure features (e.g., roundtrip), and station/location attributes used by models. We then perform a strict temporal split (Train → Validation → Test).

# %%
# !python phase2_feature_engineering.py
# Out:
# [INFO] Loading Phase 1 dataset from: data/processed/full_bike_dataset_phase1.parquet
# [INFO] Validating Phase 1 input schema...
# [INFO] Filtering trips with invalid durations (negative or > 24h)...
# [INFO] Found 0 trips with invalid durations.
# [INFO] No invalid durations found; no rows removed.
# [INFO] Adding time-based features...
# [INFO] Adding behavioral features (is_roundtrip, log-duration)...
# [INFO] Running Phase 2 summary checks...
#
# ================================================================================
# PHASE 2 SUMMARY: FEATURE ENGINEERING OVERVIEW
# ================================================================================
#
# [1] SHAPE
#   Rows   : 5,772,527
#   Columns: 29
#
# [2] DATE RANGE (started_at_parsed)
#   Min: 2024-04-01 00:00:42
#   Max: 2025-03-31 23:50:16.157000
#
# [3] TRIP DURATION SUMMARY AFTER FILTERING (minutes)
# count    5.772527e+06
# mean     1.527964e+01
# std      2.990354e+01
# min      0.000000e+00
# 1%       2.954000e-01
# 5%       2.250600e+00
# 50%      9.651567e+00
# 95%      4.205955e+01
# 99%      9.407585e+01
# max      1.439935e+03
# Name: trip_duration_min, dtype: float64
#
#     Sanity checks (post-filter):
#       Negative durations (< 0 min): 0
#       > 24 hours (> 1440 min)     : 0
#
# [4] TIME FEATURE CHECKS
#   Year counts:
# year
# 2024    5184236
# 2025     588291
# Name: count, dtype: int64
#
#   Month counts:
# month
# 1     138582
# 2     151832
# 3     297877
# 4     414450
# 5     608760
# 6     709553
# 7     747838
# 8     754801
# 9     820136
# 10    615688
# 11    334734
# 12    178276
# Name: count, dtype: int64
#
#   Weekday counts (0=Mon,...,6=Sun):
# weekday
# 0    777182
# 1    781124
# 2    851853
# 3    816259
# 4    853970
# 5    923102
# 6    769037
# Name: count, dtype: int64
#
#   is_weekend value counts:
# is_weekend
# False    4080388
# True     1692139
# Name: count, dtype: int64
#
# [5] RIDER TYPE BREAKDOWN (member_casual)
# member_casual
# member    3643137
# casual    2129390
# Name: count, dtype: int64
#
# [6] BIKE TYPE BREAKDOWN (rideable_type)
# rideable_type
# electric_bike       3051469
# classic_bike        2576721
# electric_scooter     144337
# Name: count, dtype: int64
#
# [7] ROUNDTRIP FLAG
# is_roundtrip
# False    5552786
# True      219741
# Name: count, dtype: int64
#
# [8] SAMPLE ROWS (with engineered features)
#             ride_id member_casual  ... is_weekend is_roundtrip
# 0  743252713F32516B        member  ...      False        False
# 1  BE90D33D2240C614        member  ...      False        False
# 2  D47BBDDE7C40DD61        member  ...       True        False
# 3  6684E760BF9EA9B5        member  ...      False        False
# 4  CA9EFC0D24C24A27        member  ...      False        False
#
# [5 rows x 13 columns]
#
# ================================================================================
# End of Phase 2 summary. If everything above looks reasonable,
# the dataset is ready for Phase 3 (task-specific modeling pipelines).
# ================================================================================
#
# [INFO] Saving Phase 2 dataset...
#
# [INFO] Phase 2 dataset saved to: data/processed/full_bike_dataset_phase2.parquet

# %% [markdown]
# # Phase 3: Build datasets and artifacts

# %% [markdown]
# This phase converts engineered features into model-ready tensors/tables. We build and save station vocabularies/ID mappings, apply normalization/scaling to numerical features, and generate final datasets for both the baselines and HVAE training. Outputs are saved as reusable artifacts so experiments are reproducible and consistent across runs.

# %%
# !python phase3_build_datasets.py
# Out:
# [INFO] Loading Phase 2 dataset from: data/processed/full_bike_dataset_phase2.parquet
# [INFO] Validating Phase 2 schema...
# [INFO] Computing demand contribution target (start_station_day_share)...
# [INFO] Encoding categorical columns...
# [INFO] Encoding categorical column 'start_station_id'...
# [INFO] Encoding categorical column 'end_station_id'...
# [INFO] Encoding categorical column 'rideable_type'...
# [INFO] Encoding categorical column 'member_casual'...
# [INFO] Adding integer versions of boolean flags...
# [INFO] Performing time-based train/val/test split...
# [INFO] Time-based split sizes:
#   Train: 5,322,818
#   Val  : 151,832
#   Test : 297,877
# [INFO] Imputing missing numeric features and targets using train means...
# [INFO] Imputation mean for 'trip_duration_min': 15.564427
# [INFO] Imputation mean for 'trip_duration_min_log1p': 2.415799
# [INFO] Imputation mean for 'start_lat': 41.902416
# [INFO] Imputation mean for 'start_lng': -87.646130
# [INFO] Imputation mean for 'end_lat': 41.902805
# [INFO] Imputation mean for 'end_lng': -87.646357
# [INFO] Imputation mean for 'trip_duration_min': 15.564427
# [INFO] Imputation mean for 'trip_duration_min_log1p': 2.415799
# [INFO] Imputation mean for 'start_station_day_share': 0.000057
# [INFO] Imputing 14 NaNs in 'end_lat' for train split.
# [INFO] Imputing 14 NaNs in 'end_lng' for train split.
# [INFO] Imputing 5 NaNs in 'end_lat' for test split.
# [INFO] Imputing 5 NaNs in 'end_lng' for test split.
# [INFO] Computing numeric scalers from train split...
# [INFO] Numeric scaler for 'trip_duration_min': mean=15.5644, std=30.2981
# [INFO] Numeric scaler for 'trip_duration_min_log1p': mean=2.4158, std=0.8214
# [INFO] Numeric scaler for 'start_lat': mean=41.9024, std=0.0445
# [INFO] Numeric scaler for 'start_lng': mean=-87.6461, std=0.0275
# [INFO] Numeric scaler for 'end_lat': mean=41.9028, std=0.0568
# [INFO] Numeric scaler for 'end_lng': mean=-87.6464, std=0.1189
# [INFO] Applying numeric scalers to all splits...
# [INFO] Saving train/val/test splits...
# [INFO] Saved train split to: data/model_ready\train.parquet
# [INFO] Saved val split   to: data/model_ready\val.parquet
# [INFO] Saved test split  to: data/model_ready\test.parquet
# [INFO] Saving Phase 3 artifacts...
# [INFO] Saved artifacts to: data/model_ready\phase3_artifacts.pkl
# [INFO] Running Phase 3 summary...
#
# ================================================================================
# PHASE 3 SUMMARY: MODEL-READY DATASETS
# ================================================================================
#
# [1] SPLIT SIZES
#   Train: 5,322,818
#   Val  : 151,832
#   Test : 297,877
#
# [2] FEATURE CONFIG
#   Categorical index features: ['start_station_id_idx', 'end_station_id_idx', 'rideable_type_idx', 'member_casual_idx']
#   Numeric features (normalized): ['trip_duration_min_norm', 'trip_duration_min_log1p_norm', 'start_lat_norm', 'start_lng_norm', 'end_lat_norm', 'end_lng_norm', 'hour', 'weekday', 'is_weekend_int', 'is_roundtrip_int']
#   Targets: ['trip_duration_min', 'trip_duration_min_log1p', 'start_station_day_share', 'rideable_type_idx']
#
# [3] SAMPLE ROW (train)
#    start_station_id_idx  ...  rideable_type_idx
# 0                     1  ...                  1
# 1                     1  ...                  2
# 2                     2  ...                  1
# 3                     1  ...                  1
# 4                     2  ...                  2
#
# [5 rows x 18 columns]
#
# ================================================================================
# End of Phase 3 summary. Splits and artifacts are ready for the HVAE training.
# ================================================================================

# %% [markdown]
# # Phase 4–5: HVAE definition & training

# %% [markdown]
# Phase 4 trains and evaluates independent single-task baselines for each target (duration, demand contribution, rideable type). These benchmarks quantify what can be achieved without shared representations and provide a fair comparison point for measuring the benefit of multi-task learning.
#
#
# Phase 5 trains the proposed HVAE with a shared latent structure to jointly model multiple outcomes. We report test performance on all tasks using the same feature set and the same temporal test split, then compare against baselines to quantify multi-task gains.

# %%
# !python phase5_train_hvae.py --data-dir data/model_ready --checkpoint-dir checkpoints/hvae_v2 --epochs 10 --batch-size 2048 --lr 5e-4
# Out:
# [INFO] Using device: cuda
# [INFO] Loading Phase 3 artifacts from: data/model_ready\phase3_artifacts.pkl
# [INFO] Category sizes:
#   num_start_stations: 1807
#   num_end_stations  : 1802
#   num_ride_types    : 4
#   num_member_types  : 3
#   num_numeric_features: 10
# [INFO] Building datasets...
# [INFO] Building DataLoaders...
# HierarchicalVAE(
#   (emb_start_station): Embedding(1807, 32)
#   (emb_end_station): Embedding(1802, 32)
#   (emb_member): Embedding(3, 4)
#   (encoder_mlp): Sequential(
#     (0): Linear(in_features=78, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#   )
#   (fc_mu_global): Linear(in_features=256, out_features=16, bias=True)
#   (fc_logvar_global): Linear(in_features=256, out_features=16, bias=True)
#   (fc_individual_prep): Linear(in_features=272, out_features=256, bias=True)
#   (fc_mu_individual): Linear(in_features=256, out_features=16, bias=True)
#   (fc_logvar_individual): Linear(in_features=256, out_features=16, bias=True)
#   (decoder_mlp): Sequential(
#     (0): Linear(in_features=32, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#   )
#   (head_duration): Linear(in_features=256, out_features=2, bias=True)
#   (head_demand): Linear(in_features=256, out_features=1, bias=True)
#   (head_ride_type): Linear(in_features=256, out_features=4, bias=True)
# )
#
# ===== Epoch 1/10 =====
# [TRAIN] loss=2.3028, dur=-0.7662, dem=0.0005, ride=0.5633, kl_g=0.7514, kl_i=3.3056, ride_acc=72.67%
# [VAL]   loss=2.0884, dur=-1.2337, dem=0.0000, ride=0.5336, kl_g=0.3332, kl_i=3.6792, ride_acc=65.47%
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_1.pt
# [INFO] Updated best model: checkpoints/hvae_v2\best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_1.pt
#
# ===== Epoch 2/10 =====
# [TRAIN] loss=2.0500, dur=-1.3108, dem=0.0000, ride=0.5215, kl_g=0.3219, kl_i=4.2038, ride_acc=76.19%
# [VAL]   loss=1.6922, dur=-1.0331, dem=0.0000, ride=0.4157, kl_g=0.1742, kl_i=4.5460, ride_acc=80.52%
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_2.pt
# [INFO] Updated best model: checkpoints/hvae_v2\best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_2.pt
#
# ===== Epoch 3/10 =====
# [TRAIN] loss=1.8133, dur=-1.3334, dem=0.0000, ride=0.4596, kl_g=0.1894, kl_i=4.6454, ride_acc=81.62%
# [VAL]   loss=1.5896, dur=-1.4017, dem=0.0000, ride=0.4076, kl_g=0.1134, kl_i=4.6784, ride_acc=81.49%
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_3.pt
# [INFO] Updated best model: checkpoints/hvae_v2\best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_3.pt
#
# ===== Epoch 4/10 =====
# [TRAIN] loss=1.7802, dur=-1.3058, dem=0.0000, ride=0.4503, kl_g=0.1070, kl_i=4.6939, ride_acc=82.32%
# [VAL]   loss=1.6897, dur=-1.0102, dem=0.0000, ride=0.4147, kl_g=0.0638, kl_i=4.5915, ride_acc=80.60%
# [INFO] No improvement for 1 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_4.pt
#
# ===== Epoch 5/10 =====
# [TRAIN] loss=1.7474, dur=-1.3348, dem=0.0000, ride=0.4426, kl_g=0.0619, kl_i=4.8136, ride_acc=82.64%
# [VAL]   loss=1.5233, dur=-1.2937, dem=0.0000, ride=0.3850, kl_g=0.0363, kl_i=4.8022, ride_acc=82.41%
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_5.pt
# [INFO] Updated best model: checkpoints/hvae_v2\best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_5.pt
#
# ===== Epoch 6/10 =====
# [TRAIN] loss=1.7290, dur=-1.3338, dem=0.0000, ride=0.4371, kl_g=0.0364, kl_i=4.9120, ride_acc=82.82%
# [VAL]   loss=1.4529, dur=-1.3947, dem=0.0000, ride=0.3702, kl_g=0.0229, kl_i=4.9963, ride_acc=84.07%
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_6.pt
# [INFO] Updated best model: checkpoints/hvae_v2\best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_6.pt
#
# ===== Epoch 7/10 =====
# [TRAIN] loss=1.7196, dur=-1.3314, dem=0.0000, ride=0.4343, kl_g=0.0220, kl_i=4.9535, ride_acc=82.94%
# [VAL]   loss=1.4585, dur=-1.4142, dem=0.0000, ride=0.3727, kl_g=0.0136, kl_i=4.9946, ride_acc=83.40%
# [INFO] No improvement for 1 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_7.pt
#
# ===== Epoch 8/10 =====
# [TRAIN] loss=1.7095, dur=-1.3416, dem=0.0000, ride=0.4318, kl_g=0.0122, kl_i=4.9983, ride_acc=83.06%
# [VAL]   loss=1.5748, dur=-1.3910, dem=0.0000, ride=0.4005, kl_g=0.0095, kl_i=5.0096, ride_acc=81.64%
# [INFO] No improvement for 2 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_8.pt
#
# ===== Epoch 9/10 =====
# [TRAIN] loss=1.7035, dur=-1.3476, dem=0.0000, ride=0.4302, kl_g=0.0065, kl_i=5.0343, ride_acc=83.13%
# [VAL]   loss=1.5248, dur=-1.1452, dem=0.0000, ride=0.3760, kl_g=0.0032, kl_i=4.9910, ride_acc=83.06%
# [INFO] No improvement for 3 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_9.pt
#
# ===== Epoch 10/10 =====
# [TRAIN] loss=1.6707, dur=-1.3969, dem=0.0000, ride=0.4240, kl_g=0.0028, kl_i=5.0826, ride_acc=83.44%
# [VAL]   loss=1.3531, dur=-1.4112, dem=0.0000, ride=0.3465, kl_g=0.0017, kl_i=4.9818, ride_acc=85.25%
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_10.pt
# [INFO] Updated best model: checkpoints/hvae_v2\best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v2\checkpoint_epoch_10.pt
# [INFO] Loading best model from: checkpoints/hvae_v2\best_model.pt
#
# ===== Final Test Metrics =====
# [TEST] loss=1.4101, dur=-1.4064, dem=0.0000, ride=0.3606, kl_g=0.0018, kl_i=4.9751, ride_acc=84.64%
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# c:\ECE 5831 - LOCAL\ece-final-project\phase5_train_hvae.py:518: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(best_model_path, map_location=device)

# %%
# !python phase5_train_hvae_2.py  --data-dir data/model_ready  --checkpoint-dir checkpoints/hvae_v3  --batch-size 4096  --lr 5e-4
# Out:
# [INFO] Using device: cuda
# [INFO] Loading Phase 3 artifacts from: data/model_ready/phase3_artifacts.pkl
# [INFO] Category sizes:
#   num_start_stations: 1807
#   num_end_stations  : 1802
#   num_ride_types    : 4
#   num_member_types  : 3
#   numeric_feature_cols (raw): 10
# [INFO] Train n=5,322,818  Val n=151,832  Test n=297,877
# [WARN] Leakage guard: OFF. You may be leaking targets via x_num.
# [INFO] Using 10 numeric cols for x_num.
# [INFO] Using 10 numeric cols for x_num.
# [INFO] Using 10 numeric cols for x_num.
# /home/birvas/anaconda3/envs/cyclistic-hvae/lib/python3.10/site-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# HierarchicalVAE(
#   (emb_start_station): Embedding(1807, 32)
#   (emb_member): Embedding(3, 4)
#   (encoder_mlp): Sequential(
#     (0): Linear(in_features=46, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#   )
#   (fc_mu_global): Linear(in_features=256, out_features=16, bias=True)
#   (fc_logvar_global): Linear(in_features=256, out_features=16, bias=True)
#   (fc_individual_prep): Linear(in_features=272, out_features=256, bias=True)
#   (fc_mu_individual): Linear(in_features=256, out_features=16, bias=True)
#   (fc_logvar_individual): Linear(in_features=256, out_features=16, bias=True)
#   (decoder_mlp): Sequential(
#     (0): Linear(in_features=32, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#   )
#   (head_duration): Linear(in_features=256, out_features=2, bias=True)
#   (head_destination): Linear(in_features=256, out_features=1802, bias=True)
#   (head_ride_type): Linear(in_features=256, out_features=4, bias=True)
# )
# /home/birvas/anaconda3/envs/cyclistic-hvae/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#
# ===== Epoch 1/12 =====
# /home/birvas/anaconda3/envs/cyclistic-hvae/lib/python3.10/site-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# [TRAIN] loss=6.3963, dur=-0.3877, dest=4.8966, ride=0.6601, kl_g=1.1350, kl_i=4.0052, dest_acc=19.28%, ride_acc=64.42%, dur_mae_min=nan, dur_rmse_min=nan
# [VAL]   loss=5.8172, dur=-1.0747, dest=4.4517, ride=0.6128, kl_g=1.4126, kl_i=5.6844, dest_acc=17.80%, ride_acc=58.96%, dur_mae_min=0.75, dur_rmse_min=1.69
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_1.pt
# [INFO] Updated best model: checkpoints/hvae_v3/best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_1.pt
#
# ===== Epoch 2/12 =====
# [TRAIN] loss=5.6291, dur=-0.8866, dest=4.0971, ride=0.6482, kl_g=1.8206, kl_i=6.4375, dest_acc=20.43%, ride_acc=64.76%, dur_mae_min=inf, dur_rmse_min=inf
# [VAL]   loss=5.2037, dur=-1.2408, dest=3.7755, ride=0.6054, kl_g=2.1132, kl_i=7.1992, dest_acc=18.25%, ride_acc=61.60%, dur_mae_min=0.57, dur_rmse_min=1.49
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_2.pt
# [INFO] Updated best model: checkpoints/hvae_v3/best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_2.pt
#
# ===== Epoch 3/12 =====
# [TRAIN] loss=4.9209, dur=-0.9765, dest=3.3205, ride=0.6453, kl_g=2.3804, kl_i=7.7183, dest_acc=23.08%, ride_acc=64.91%, dur_mae_min=inf, dur_rmse_min=inf
# [VAL]   loss=4.8360, dur=-1.2032, dest=3.3836, ride=0.6028, kl_g=2.3878, kl_i=7.3588, dest_acc=19.77%, ride_acc=61.72%, dur_mae_min=0.66, dur_rmse_min=1.66
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_3.pt
# [INFO] Updated best model: checkpoints/hvae_v3/best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_3.pt
#
# ===== Epoch 4/12 =====
# [TRAIN] loss=291.3667, dur=-0.9141, dest=236.6217, ride=27.1769, kl_g=3.1797, kl_i=8.3017, dest_acc=26.91%, ride_acc=65.24%, dur_mae_min=inf, dur_rmse_min=inf
# [VAL]   loss=4.4153, dur=-1.3672, dest=2.9526, ride=0.5841, kl_g=3.4944, kl_i=7.8643, dest_acc=23.81%, ride_acc=66.16%, dur_mae_min=0.47, dur_rmse_min=1.52
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_4.pt
# [INFO] Updated best model: checkpoints/hvae_v3/best_model.pt
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_4.pt
#
# ===== Epoch 5/12 =====
# [TRAIN] loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=24.49%, ride_acc=28.48%, dur_mae_min=nan, dur_rmse_min=nan
# [VAL]   loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=17.91%, ride_acc=0.00%, dur_mae_min=nan, dur_rmse_min=nan
# [INFO] No improvement for 1 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_5.pt
#
# ===== Epoch 6/12 =====
# [TRAIN] loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=19.33%, ride_acc=0.00%, dur_mae_min=nan, dur_rmse_min=nan
# [VAL]   loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=17.91%, ride_acc=0.00%, dur_mae_min=nan, dur_rmse_min=nan
# [INFO] No improvement for 2 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_6.pt
#
# ===== Epoch 7/12 =====
# [TRAIN] loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=19.33%, ride_acc=0.00%, dur_mae_min=nan, dur_rmse_min=nan
# [VAL]   loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=17.91%, ride_acc=0.00%, dur_mae_min=nan, dur_rmse_min=nan
# [INFO] No improvement for 3 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_7.pt
#
# ===== Epoch 8/12 =====
# [TRAIN] loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=19.33%, ride_acc=0.00%, dur_mae_min=nan, dur_rmse_min=nan
# [VAL]   loss=nan, dur=nan, dest=nan, ride=nan, kl_g=nan, kl_i=nan, dest_acc=17.91%, ride_acc=0.00%, dur_mae_min=nan, dur_rmse_min=nan
# [INFO] No improvement for 4 epoch(s).
# [INFO] Saved checkpoint: checkpoints/hvae_v3/checkpoint_epoch_8.pt
# [INFO] Early stopping triggered (patience=4).
#
# [INFO] Loading best model from: checkpoints/hvae_v3/best_model.pt
# /home/birvas/Desktop/ece-project/phase5_train_hvae.py:523: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(best_path, map_location=device)
#
# ===== Final Test Metrics =====
# [TEST]  loss=4.3935, dur=-1.3667, dest=2.9369, ride=0.5757, kl_g=3.5569, kl_i=8.0129, dest_acc=26.35%, ride_acc=66.27%, dur_mae_min=0.58, dur_rmse_min=1.79

# %% [markdown]
# # Phase 6: Anomaly scoring

# %% [markdown]
# This phase uses reconstruction-based anomaly scores to flag unusual trips without supervision. We analyze the score distribution, select operational percentile thresholds (e.g., p95/p99), and qualitatively inspect high-scoring trips to categorize anomaly types (temporal, behavioral, spatial, and vehicle mismatch).

# %%
# !python phase6_anomaly_scoring.py --data-dir data/model_ready --checkpoint-path checkpoints/hvae_v2/best_model.pt --split test --output-dir data/anomaly_scores --batch-size 4096 --device cuda
# Out:
# [INFO] Using device: cuda
# [INFO] Loading Phase 3 artifacts from: data/model_ready\phase3_artifacts.pkl
# [INFO] Category sizes for model reconstruction:
#   num_start_stations: 1807
#   num_end_stations  : 1802
#   num_ride_types    : 4
#   num_member_types  : 3
#   num_numeric_features: 10
# [INFO] Loading model checkpoint from: checkpoints/hvae_v2/best_model.pt
# [INFO] Building anomaly dataset for split='test'...
# [INFO] Computing anomaly scores on 297,877 samples...
#   [INFO] Processed 204,800 samples...
#
# ================================================================================
# ANOMALY SCORE SUMMARY (test split)
# ================================================================================
# count    297877.000000
# mean         -1.039350
# std          21.731602
# min          -5.626651
# 50%          -1.601471
# 90%          -0.902468
# 95%          -0.273548
# 99%           3.682961
# max        8967.341797
# Name: anomaly_score, dtype: float64
#
# [TOP 10 MOST ANOMALOUS TRIPS]
#                  ride_id       started_at_parsed  ... anomaly_score anomaly_rank
# 171004  7E66493C044A73FE 2025-03-24 23:23:26.152  ...   8967.341797            1
# 76658   6B562428E92AB639 2025-03-27 07:43:48.968  ...   1542.847778            2
# 165874  AE92BDE50733172C 2025-03-21 07:00:50.850  ...   1442.158691            3
# 21658   EAC316BB0895A286 2025-03-24 06:35:00.523  ...   1428.127441            4
# 165588  24CD0FAB34A52C62 2025-03-26 07:34:58.460  ...   1412.540283            5
# 200527  E63B6291EB72D1EA 2025-03-18 07:38:44.767  ...   1397.055664            6
# 61846   38C6B16BC5D09D3C 2025-03-12 06:23:00.797  ...   1366.124390            7
# 162307  D8543E5C949998F6 2025-03-30 12:17:42.037  ...   1304.171997            8
# 54824   CAD3794F728ABBDA 2025-03-27 16:45:28.866  ...   1220.176636            9
# 198762  7BAA7412C36CC7EB 2025-03-29 15:15:54.617  ...   1202.811157           10
#
# [10 rows x 10 columns]
#
# [INFO] Saved anomaly-scored test split to: data/anomaly_scores\anomaly_scores_test.parquet
# c:\ECE 5831 - LOCAL\ece-final-project\phase6_anomaly_scoring.py:186: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(checkpoint_path, map_location=device)

# %% [markdown]
# # Phase 7: Latent Space Analysis (Intent Discovery)

# %% [markdown]
# This phase evaluates interpretability of the learned global latent space by extracting latent codes and applying clustering (e.g., k-means). We summarize cluster-level behavior (duration, casual/member share, weekend share, roundtrips, peak hour patterns) to identify “intent-like” modes such as commute, leisure, and tourism.

# %%
# !python phase7_latent_analysis.py --data-dir data/model_ready --anomaly-path data/anomaly_scores/anomaly_scores_test.parquet --checkpoint-path checkpoints/hvae_v2/best_model.pt --split test --output-dir data/latent_analysis --num-clusters 8 --batch-size 4096 --device cuda
# Out:
# [INFO] Using device: cuda
# [INFO] Loading Phase 3 artifacts from: data/model_ready\phase3_artifacts.pkl
# [INFO] Category sizes for model reconstruction:
#   num_start_stations: 1807
#   num_end_stations  : 1802
#   num_ride_types    : 4
#   num_member_types  : 3
#   num_numeric_features: 10
# [INFO] Loading model checkpoint from: checkpoints/hvae_v2/best_model.pt
# [INFO] Building latent dataset from: data/anomaly_scores/anomaly_scores_test.parquet
# [INFO] Extracting latents for 297,877 samples...
#   [INFO] Processed 204,800 samples...
# [INFO] Latent shapes: z_global=(297877, 16), z_individual=(297877, 16)
# [INFO] Running k-means with K=8 on z_global...
#
# ================================================================================
# CLUSTER SUMMARY (split=test, K=8)
# ================================================================================
#
# [Cluster sizes]
# intent_cluster
# 0    61219
# 1    40764
# 2    43541
# 3    22789
# 4    55084
# 5     9656
# 6     3696
# 7    61128
# Name: count, dtype: int64
#
# [Cluster: duration & anomaly stats]
#                 n_trips  mean_duration  median_duration  mean_anom    p95_anom
# intent_cluster
# 0                 61219       8.186284         8.107267  -1.515805   -0.842311
# 1                 40764      20.111388        19.433400  -1.501176    0.482855
# 2                 43541       2.991045         3.054300  -1.442705   -0.909750
# 3                 22789      36.736667        34.303217  -0.897818    4.089222
# 4                 55084      12.516465        12.282400  -1.554907   -0.476025
# 5                  9656       0.676778         0.548858  -1.473539   -0.986348
# 6                  3696     134.858327        85.634967  31.828026  138.143105
# 7                 61128       5.258388         5.232975  -1.473771   -0.925856
#
# [Cluster: rideable_type distribution (% within cluster)]
# rideable_type   classic_bike  electric_bike
# intent_cluster
# 0                      35.58          64.42
# 1                      42.77          57.23
# 2                      34.77          65.23
# 3                      50.71          49.29
# 4                      38.35          61.65
# 5                      13.71          86.29
# 6                      47.84          52.16
# 7                      33.73          66.27
#
# [Cluster: member_casual distribution (% within cluster)]
# member_casual   casual  member
# intent_cluster
# 0                26.73   73.27
# 1                34.42   65.58
# 2                18.67   81.33
# 3                46.67   53.33
# 4                29.25   70.75
# 5                35.76   64.24
# 6                66.80   33.20
# 7                23.67   76.33
#
# [INFO] Saved latent-enriched test split to: data/latent_analysis\latent_analysis_test.parquet
# c:\ECE 5831 - LOCAL\ece-final-project\phase7_latent_analysis.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(checkpoint_path, map_location=device)

# %% [markdown]
# ## Phase 8: Case studies

# %% [markdown]
# Phase 8 runs case studies, this is typically where we take representative trips or clusters and explain model behavior in a more concrete way, including why certain trips appear unusual.

# %%
# !python phase8_case_studies.py --input-path data/latent_analysis/latent_analysis_test.parquet --split test --output-dir data/case_studies --top-k-global 200 --top-k-per-cluster 50 --p95-thresh 0.95 --p99-thresh 0.99
# Out:
# [INFO] Loading latent+anomaly data from: data/latent_analysis/latent_analysis_test.parquet
# [INFO] Selecting global top-200 anomalies...
# [INFO] Saved global top-200 anomalies to:
#        data/case_studies\global_top200_anomalies_test.parquet
#        data/case_studies\global_top200_anomalies_test.csv
# [INFO] Selecting top-50 anomalies per cluster...
# [INFO] Saved per-cluster top-50 anomalies to:
#        data/case_studies\cluster_top50_anomalies_test.parquet
#        data/case_studies\cluster_top50_anomalies_test.csv
# [INFO] Computing threshold-based anomaly flags...
#   [STATS] p95 threshold (top 5%): -0.2735
#           Count >= p95: 14894 (5.00 % of trips)
#   [STATS] p99 threshold (top 1%): 3.6830
#           Count >= p99: 2979 (1.00 % of trips)
# [INFO] Saved latent+flags dataframe to: data/case_studies\latent_with_flags_test.parquet
#
# [Cluster-level anomaly counts (p99 flag)]
#                 n_anom_p99  n_total  pct_anom_p99
# intent_cluster
# 0                        2    61219          0.00
# 1                      262    40764          0.64
# 2                        0    43541          0.00
# 3                     1279    22789          5.61
# 4                       25    55084          0.05
# 5                        0     9656          0.00
# 6                     1411     3696         38.18
# 7                        0    61128          0.00

# %%
# !python phase9_plots_and_results.py
# Out:
# [INFO] Using device: cuda
# [INFO] Loading Phase 3 artifacts from: data/model_ready\phase3_artifacts.pkl
# [INFO] Loading model checkpoint from: checkpoints/hvae_v2/best_model.pt
#
# === Rideable-type classification (test) ===
#
# [RESULT] Test rideable_type accuracy: 84.70%
#
# [CONFUSION MATRIX (raw counts)]
# [[     0      0      0      0]
#  [     0  94324  16427      0]
#  [     0  29132 157992      2]
#  [     0      0      0      0]]
#
# [CLASSIFICATION REPORT]
#                   precision    recall  f1-score   support
#
#            <UNK>       0.00      0.00      0.00         0
#     classic_bike       0.76      0.85      0.81    110751
#    electric_bike       0.91      0.84      0.87    187126
# electric_scooter       0.00      0.00      0.00         0
#
#         accuracy                           0.85    297877
#        macro avg       0.42      0.42      0.42    297877
#     weighted avg       0.85      0.85      0.85    297877
#
# [INFO] Saved confusion matrix figure to: figures\fig_rideable_confusion_test.png
#
# === Anomaly score distribution (test) ===
# [INFO] Saved anomaly histogram figure to: figures\fig_anomaly_hist_test.png
#
# === Cluster-level anomaly rates (p99) ===
#
# [Cluster-level anomaly rates (p99 flag)]
#                 n_anom_p99  n_total  pct_anom_p99
# intent_cluster
# 0                        2    61219          0.00
# 1                      262    40764          0.64
# 2                        0    43541          0.00
# 3                     1279    22789          5.61
# 4                       25    55084          0.05
# 5                        0     9656          0.00
# 6                     1411     3696         38.18
# 7                        0    61128          0.00
# [INFO] Saved cluster anomaly rate figure to: figures\fig_cluster_anomaly_rate_p99_test.png
#
# [SUMMARY]
#   Test rideable-type accuracy: 84.70%
#   Anomaly score p95 (top 5%): -0.2735
#   Anomaly score p99 (top 1%): 3.6830
#   Cluster-level p99 anomaly rates (%):
# intent_cluster
# 0     0.00
# 1     0.64
# 2     0.00
# 3     5.61
# 4     0.05
# 5     0.00
# 6    38.18
# 7     0.00
# Name: pct_anom_p99, dtype: float64
# c:\ECE 5831 - LOCAL\ece-final-project\phase9_plots_and_results.py:76: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(checkpoint_path, map_location=device)
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\bnsev\anaconda3\envs\cyclistic-hvae\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
